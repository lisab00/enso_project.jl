# %%
cd("$(homedir())/Documents/Repos/enso_project.jl")
using Pkg
Pkg.activate(".")
# Out:
#   Activating project at `C:\Users\lisah\Documents\Repos\enso_project.jl`

# %%
using ReservoirComputing, CSV, DataFrames, DynamicalSystems, Plots, enso_project
# Out:
# ┌ Warning: Package cuDNN not found in current path.
# │ - Run `import Pkg; Pkg.add("cuDNN")` to install the cuDNN package, then restart julia.
# │ - If cuDNN is not installed, some Flux functionalities will not be available when running on the GPU.
# └ @ FluxCUDAExt C:\Users\lisah\.julia\packages\Flux\9PibT\ext\FluxCUDAExt\FluxCUDAExt.jl:10

# %% [markdown]
# # Train ESN on ENSO with TDE

# %% [markdown]
# First do split, then do embedding!

# %% [markdown]
# ## Data preperations

# %% [markdown]
# ### Train, val, test split

# %%
sst_1D = CSV.read("data/sst_data/sst_34_format.csv", DataFrame)
train_sst_1D = sst_1D[1:400, "ANOM_3"]
val_sst_1D = sst_1D[401:450, "ANOM_3"]
test_sst_1D = sst_1D[451:500, "ANOM_3"];

# %% [markdown]
# ### Data embedding

# %% [markdown]
# Perform embedding on training data and then use same embedding for validation data

# %%
train_sst_emb, τ, E = optimal_separated_de(train_sst_1D) 
train_sst_emb = Matrix(train_sst_emb)';
# Out:
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.

# %%
val_sst_emb = embed(val_sst_1D, size(train_sst_emb,1), τ)
val_sst_emb = Matrix(val_sst_emb)';

# %% [markdown]
# ## Network training v1

# %% [markdown]
# take first column of prediction and shift

# %% [markdown]
# #### tools

# %%
function esn_eval_pred(esn::ESN, W_out, steps_to_predict::Int64, τ::Int64)
    prediction = esn(Generative(steps_to_predict), W_out)
    return prediction[1,τ+1:end] # changed this line
end

function plot_esn_prediction(esn::ESN, W_out, data::AbstractMatrix, τ::Int64)
    steps_to_predict = size(data,2)
    prediction = esn_eval_pred(esn, W_out, steps_to_predict, τ) # changed this line
    
    label = ["actual" "predicted"]
    times =  collect(0:size(test_sst_1D',2)-τ)[1:end-1] # changed this line
    
    plot(times, [data[1,1:end-τ], prediction], label=label, ylabel="ONI", xlabel="Months", title="Prediction of ENSO using an ESN")
end


function cross_validate_esn(train_data::AbstractMatrix, val_data::AbstractMatrix, param_grid::Vector, τ::Int64)
    best_loss = Inf
    best_params = nothing

    # We want to predict one step ahead, so the input signal is equal to the target signal from the previous step
    # i.e. the sequence is shifted by one step
    u_train = train_data[:, 1:end-1]
    y_train = train_data[:, 2:end]
        
    for hyperparams in param_grid        
        # Unpack the hyperparams struct
        (; reservoir_size, spectral_radius, sparsity, input_scale, ridge_param) = hyperparams

        # Generate and train an ESN
        esn = ESN(
            u_train,
            size(train_data, 1),
            reservoir_size;
            reservoir=rand_sparse(; radius=spectral_radius, sparsity=sparsity),
            input_layer=scaled_rand(; scaling=input_scale),
        )
        Wₒᵤₜ = enso_project.train_esn!(esn, y_train, ridge_param)

        # Evaluate the loss on the validation set
        steps_to_predict = size(val_data[:, τ+1:end], 2) # changed this line
        prediction = esn(Generative(steps_to_predict), Wₒᵤₜ)
        loss = sum(abs2, prediction - val_data[:, τ+1:end]) # changed this line. this is wrong TODO
        
        # Keep track of the best hyperparameter values
        if loss < best_loss
            best_loss = loss
            best_params = hyperparams
            println(best_params)
            println("Validation loss = $best_loss")
        end
    end
    
    # Retrain the model using the optimal hyperparameters on both the training and validation data
    # This is necessary because we don't want errors incurred during validation to affect the test error
    (;reservoir_size, spectral_radius, sparsity, input_scale, ridge_param) = best_params
    data = hcat(train_data, val_data)
    u = data[:, 1:end-1]
    y = data[:, 2:end]
    esn = ESN(
        u,
        size(train_data, 1),
        reservoir_size;
        reservoir=rand_sparse(; radius=spectral_radius, sparsity=sparsity),
        input_layer=scaled_rand(; scaling=input_scale),
    )
    Wₒᵤₜ = enso_project.train_esn!(esn, y, ridge_param)
    
    return esn, Wₒᵤₜ, best_loss
end
# Out:
# cross_validate_esn (generic function with 1 method)

# %% [markdown]
# #### training

# %%
"""spectral_radii = [0.8,0.9,1.0]
sparsities = [0.05, 0.1, 0.2]
input_scales = [0.1,0.8,1.0]
ridge_values = [0.0, 1e-6, 1e-5]
reservoir_sizes = [100,150,200]"""

spectral_radii = [0.8,1.0]
sparsities = [0.05, 0.1]
input_scales = [0.1,0.8,1.0]
ridge_values = [0.0, 1e-6, 1e-5]
reservoir_sizes = [100,110,120,130,140,150,160,170,180,190,200]

param_grid = enso_project.create_param_grid(reservoir_sizes, spectral_radii, sparsities, input_scales, ridge_values);

# %%
esn, W_out, val_loss = cross_validate_esn(train_sst_emb, val_sst_emb, param_grid, τ)
# Out:
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 11.242832245532416
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 10.830666731545621
# enso_project.ESNHyperparams(140, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 10.553887381867195
# enso_project.ESNHyperparams(150, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 9.5474980656111
# enso_project.ESNHyperparams(170, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 8.526116746612951
# enso_project.ESNHyperparams(140, 1.0, 0.1, 0.1, 0.0)
# Validation loss = 8.122853767181988
# enso_project.ESNHyperparams(200, 1.0, 0.05, 0.8, 0.0)
# Validation loss = 7.632959691715742
# (ESN(5 => 200), OutputLayer successfully trained with output size: 5, 7.632959691715742)

# %% [markdown]
# ### Plot Prediction

# %%
plot_esn_prediction(esn, W_out, test_sst_1D', τ)

# %% [markdown]
# ## Network training v2

# %% [markdown]
# take last column of prediction

# %% [markdown]
# #### tools

# %%
function esn_eval_pred(esn::ESN, W_out, data::AbstractMatrix)
    steps_to_predict = size(data,2)
    prediction = esn(Generative(steps_to_predict), W_out)
    return prediction[end,:] # changed this line
end

function plot_esn_prediction(esn::ESN, W_out, data::AbstractMatrix, data_name::String)
    prediction = esn_eval_pred(esn, W_out, data)
    
    label = ["actual" "predicted"]
    times =  collect(0:size(data,2))[1:end-1]

    plot(times, [data[1,:], prediction], label=label, ylabel="ONI", xlabel="Months", title="Prediction of ENSO using an ESN $data_name")
end

function cross_validate_esn(train_data::AbstractMatrix, val_data::AbstractMatrix, param_grid::Vector)
    best_loss = Inf
    best_params = nothing

    # We want to predict one step ahead, so the input signal is equal to the target signal from the previous step
    # i.e. the sequence is shifted by one step
    u_train = train_data[:, 1:end-1]
    y_train = train_data[:, 2:end]
        
    for hyperparams in param_grid        
        # Unpack the hyperparams struct
        (; reservoir_size, spectral_radius, sparsity, input_scale, ridge_param) = hyperparams

        # Generate and train an ESN
        esn = ESN(
            u_train,
            size(train_data, 1),
            reservoir_size;
            reservoir=rand_sparse(; radius=spectral_radius, sparsity=sparsity),
            input_layer=scaled_rand(; scaling=input_scale),
        )
        Wₒᵤₜ = enso_project.train_esn!(esn, y_train, ridge_param)

        # Evaluate the loss on the validation set
        steps_to_predict = size(val_data, 2)
        prediction = esn(Generative(steps_to_predict), Wₒᵤₜ)
        loss = sum(abs2, prediction[end, :] - val_data[1, :]) # changed this line
        
        # Keep track of the best hyperparameter values
        if loss < best_loss
            best_loss = loss
            best_params = hyperparams
            println(best_params)
            println("Validation loss = $best_loss")
        end
    end
    
    # Retrain the model using the optimal hyperparameters on both the training and validation data
    # This is necessary because we don't want errors incurred during validation to affect the test error
    (;reservoir_size, spectral_radius, sparsity, input_scale, ridge_param) = best_params
    data = hcat(train_data, val_data)
    u = data[:, 1:end-1]
    y = data[:, 2:end]
    esn = ESN(
        u,
        size(train_data, 1),
        reservoir_size;
        reservoir=rand_sparse(; radius=spectral_radius, sparsity=sparsity),
        input_layer=scaled_rand(; scaling=input_scale),
    )
    Wₒᵤₜ = enso_project.train_esn!(esn, y, ridge_param)
    
    return esn, Wₒᵤₜ, best_loss
end
# Out:
# cross_validate_esn (generic function with 2 methods)

# %% [markdown]
# ### training

# %%
spectral_radii = [0.8,0.9,1.0]
sparsities = [0.05, 0.1]
input_scales = [0.1,0.8,1.0]
ridge_values = [0.0, 1e-6, 1e-5]
reservoir_sizes = [100,110,120,130,140,150,160,170,180,190,200]

param_grid = enso_project.create_param_grid(reservoir_sizes, spectral_radii, sparsities, input_scales, ridge_values);

# %%
esn, W_out, val_loss = cross_validate_esn(train_sst_emb, val_sst_emb, param_grid)
# Out:
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 39.152044294369254
# enso_project.ESNHyperparams(170, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 30.5030377053533
# enso_project.ESNHyperparams(180, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 23.797818102329753
# enso_project.ESNHyperparams(190, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 22.02483896020752
# enso_project.ESNHyperparams(190, 0.9, 0.05, 0.1, 0.0)
# Validation loss = 21.14516260780882
# enso_project.ESNHyperparams(120, 1.0, 0.05, 0.1, 0.0)
# Validation loss = 20.514115140182806
# enso_project.ESNHyperparams(170, 1.0, 0.05, 0.1, 0.0)
# Validation loss = 17.01100252384308
# enso_project.ESNHyperparams(130, 0.8, 0.05, 0.8, 0.0)
# Validation loss = 9.98188295948097
# enso_project.ESNHyperparams(180, 0.9, 0.1, 0.8, 0.0)
# Validation loss = 9.828382556671304
# enso_project.ESNHyperparams(180, 0.9, 0.1, 1.0, 0.0)
# Validation loss = 9.315370553694091
# enso_project.ESNHyperparams(200, 1.0, 0.1, 1.0, 0.0)
# Validation loss = 8.29896878274248
# (ESN(5 => 200), OutputLayer successfully trained with output size: 5, 8.29896878274248)

# %%
plot_esn_prediction(esn, W_out, test_sst_1D', "")

# %% [markdown]
# ## error analysis

# %%
train_size = 250
initial_val_size = 40;

# %%
N = 100
L = 30;

# %% [markdown]
# ### tools

# %%
function sample_lead_times(L, N, data, train_size, initial_val_size, param_grid)
    datasets_test = zeros(N,L)
    predictions = zeros(N,L)

    for n in 0:(N-1)
        # include data shift n
        train_data = data[1:train_size]
        val_data = data[train_size+1:train_size+initial_val_size+n]
        test_data = data[train_size+initial_val_size+n+1:train_size+initial_val_size+n+L]

        # perform data embedding
        train_data_emb, τ, E = optimal_separated_de(train_data)
        train_data_emb = Matrix(train_data_emb)'
        val_data_emb = embed(val_data, size(train_data_emb,1), τ)
        val_data_emb = Matrix(val_data_emb)'

        # train
        esn, W_out, val_loss = cross_validate_esn(train_data_emb, val_data_emb, param_grid) 
        prediction = esn_eval_pred(esn, W_out, test_data')

        # store 
        datasets_test[n+1,:] = test_data
        predictions[n+1,:] = prediction

        # progress control
        println("Finished sample $(n+1)")
    end
    return predictions, datasets_test
end
# Out:
# sample_lead_times (generic function with 1 method)

# %%
"""
    function rmse(predictions::AbstractMatrix, test_data::AbstractMatrix)
       
compute the rmse between predicitons and test data for each lead time. Is considered good if smaller 1.4.

# Arguments:
    - `predicitons::AbstractMatrix`: predictions, NxL matrix. N is sample size per lead time, L is all lead times considered
    - `test_data::AbstractMatrix`: test data for each sample, NxL matrix.

# Returns:
    - `Vector`: RMSE for each lead time, vector of length L
"""
function rmse(predictions::AbstractMatrix, test_data::AbstractMatrix)
    N, L = size(predictions, 1), size(predictions,2)
    sse_vals = zeros(N,L)
    sse_vals = (predictions .- test_data).^2
    rmse = sqrt.(sum(sse_vals, dims=1) ./N)
    return rmse[1,:]
end

"""
    function pcc(predictions::AbstractMatrix, test_data::AbstractMatrix)

Compute the Pearson-Correlation-Coefficient between sample and test data for each lead time considered. I.e., PCC is computed between respective data columns.
Is considered good, if > 0.5.

# Arguments:
    - `predicitons::AbstractMatrix`:  predictions, NxL matrix. N is sample size per lead time, L is all lead times considered
    - `test_data::AbstractMatrix`: test data for each sample, NxL matrix.

# Returns:
    - `Vector`: PCC for each lead time, vector of length L
"""
function pcc(predictions::AbstractMatrix, test_data::AbstractMatrix)
    L = size(predictions, 2)
    return [cor(predictions[:,i], test_data[:,i]) for i in 1:L]
end

"""
    function hss(predictions::AbstractMatrix, test_data::AbstractMatrix)

Measures accuracy of predictions (wrt randomly generated forecast). ENSO predicted if abs(ONI)>0.5. Compute ratio out of TP,TN,FP,FN.
Is considered good if >0.5.
Formula from paper "Long-term ENSO prediction with echo-state networks" by Hassanibesheli F. et al.

# Arguments:
    - `predicitons::AbstractMatrix`:  predictions, NxL matrix. N is sample size per lead time, L is all lead times considered
    - `test_data::AbstractMatrix`: test data for each sample, NxL matrix.

# Returns:
    - `Vector`: HSS for each lead time, vector of length L
"""
function hss(predictions::AbstractMatrix, test_data::AbstractMatrix)

    # predict event if indec > 0.5
    events_pred = abs.(Int.(round.(predictions)))
    events_true = abs.(Int.(round.(test_data)))

    # compute TN
    TN_mat = events_pred + events_true
    TN = sum(TN_mat .== 0, dims=1)

    # compute FP,FN,TP
    compare = events_pred - events_true # matrix: 0 for TP, TN; 1 for FP, -1 for FN
    FP = sum(compare .== 1, dims=1)
    FN = sum(compare .==-1, dims=1)
    TP = sum(compare .==0, dims=1) .- TN

    N = TN + TP + FN + FP # should be sample size

    # calculate formula
    CRF = ((TP .+ FN) .* (TP .+ FP) .+ (TN .+ FN) .* (TN .+ FP)) ./ N
    HSS = (TP .+ TN .- CRF) ./ (N .- CRF)
    return HSS[1,:]
end
# Out:
# hss

# %% [markdown]
# ### generate samples

# %%
data = sst_1D[!,"ANOM_3"];

# %%
predictions, datasets_test = sample_lead_times(L,N,data, train_size, initial_val_size,param_grid);
# Out:
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 23.40981835882758
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 21.32656684094738
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 8.044787003738161
# enso_project.ESNHyperparams(130, 0.9, 0.05, 0.8, 0.0)
# Validation loss = 5.871614746106744
# enso_project.ESNHyperparams(160, 1.0, 0.05, 0.8, 0.0)
# Validation loss = 5.17186396971494
# enso_project.ESNHyperparams(120, 0.9, 0.1, 0.8, 0.0)
# Validation loss = 2.771066733066239
# Finished sample 1
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 27.68502446186255
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 25.5890835469613
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 8.419782022766263
# enso_project.ESNHyperparams(130, 0.9, 0.05, 0.8, 0.0)
# Validation loss = 8.22724615553419
# enso_project.ESNHyperparams(160, 1.0, 0.05, 0.8, 0.0)
# Validation loss = 5.245042930361204
# enso_project.ESNHyperparams(120, 0.9, 0.1, 0.8, 0.0)
# Validation loss = 2.776426106493243
# Finished sample 2
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 32.563564415434556
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 30.163581887975536
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 8.853943177951814
# enso_project.ESNHyperparams(160, 1.0, 0.05, 0.8, 0.0)
# Validation loss = 5.578061811643869
# enso_project.ESNHyperparams(120, 0.9, 0.1, 0.8, 0.0)
# Validation loss = 3.969836932557464
# enso_project.ESNHyperparams(120, 0.9, 0.1, 0.8, 1.0e-6)
# Validation loss = 3.9694513874257877
# enso_project.ESNHyperparams(120, 0.9, 0.1, 0.8, 1.0e-5)
# Validation loss = 3.9660008029025073
# Finished sample 3
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 37.47631860705412
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 34.844113523641255
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 9.297014926434937
# enso_project.ESNHyperparams(160, 1.0, 0.05, 0.8, 0.0)
# Validation loss = 6.282556762576828
# enso_project.ESNHyperparams(120, 0.9, 0.1, 0.8, 0.0)
# Validation loss = 5.709034454197927
# enso_project.ESNHyperparams(120, 0.9, 0.1, 0.8, 1.0e-6)
# Validation loss = 5.708693870269099
# enso_project.ESNHyperparams(120, 0.9, 0.1, 0.8, 1.0e-5)
# Validation loss = 5.705579047798593
# Finished sample 4
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 40.378587787147545
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 37.880507559291914
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 9.39662750287277
# enso_project.ESNHyperparams(160, 1.0, 0.05, 0.8, 0.0)
# Validation loss = 6.897945774661962
# enso_project.ESNHyperparams(120, 0.9, 0.1, 0.8, 0.0)
# Validation loss = 5.776992283656503
# enso_project.ESNHyperparams(120, 0.9, 0.1, 0.8, 1.0e-6)
# Validation loss = 5.77640052978249
# enso_project.ESNHyperparams(120, 0.9, 0.1, 0.8, 1.0e-5)
# Validation loss = 5.771084057797556
# Finished sample 5
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 42.64238695737461
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 40.267998345912034
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 9.542688761649998
# enso_project.ESNHyperparams(160, 1.0, 0.05, 0.8, 0.0)
# Validation loss = 7.223298265456128
# enso_project.ESNHyperparams(120, 0.9, 0.1, 0.8, 0.0)
# Validation loss = 5.823164534818759
# enso_project.ESNHyperparams(120, 0.9, 0.1, 0.8, 1.0e-6)
# Validation loss = 5.822488454185559
# enso_project.ESNHyperparams(120, 0.9, 0.1, 0.8, 1.0e-5)
# Validation loss = 5.816480306807802
# Finished sample 6
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 44.03098161164008
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 41.314745892091466
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 9.593556869323356
# enso_project.ESNHyperparams(160, 1.0, 0.05, 0.8, 0.0)
# Validation loss = 7.341626228779741
# enso_project.ESNHyperparams(120, 0.9, 0.1, 0.8, 0.0)
# Validation loss = 6.701467305494786
# enso_project.ESNHyperparams(120, 0.9, 0.1, 0.8, 1.0e-6)
# Validation loss = 6.6987188460684255
# enso_project.ESNHyperparams(120, 0.9, 0.1, 0.8, 1.0e-5)
# Validation loss = 6.673828847878864
# Finished sample 7
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 45.127800828213644
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 41.610343086241166
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 9.680283180130138
# enso_project.ESNHyperparams(160, 1.0, 0.05, 0.8, 0.0)
# Validation loss = 7.4939980533755755
# enso_project.ESNHyperparams(120, 0.9, 0.1, 0.8, 0.0)
# Validation loss = 7.128093457471446
# enso_project.ESNHyperparams(120, 0.9, 0.1, 0.8, 1.0e-6)
# Validation loss = 7.1209683344509145
# enso_project.ESNHyperparams(120, 0.9, 0.1, 0.8, 1.0e-5)
# Validation loss = 7.057985752398915
# Finished sample 8
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 45.961530483834906
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 41.62044175276741
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 9.756441747221041
# enso_project.ESNHyperparams(160, 1.0, 0.05, 0.8, 0.0)
# Validation loss = 7.4974425363394435
# enso_project.ESNHyperparams(120, 0.9, 0.1, 0.8, 0.0)
# Validation loss = 7.135844840721106
# enso_project.ESNHyperparams(120, 0.9, 0.1, 0.8, 1.0e-6)
# Validation loss = 7.1289656095292
# enso_project.ESNHyperparams(120, 0.9, 0.1, 0.8, 1.0e-5)
# Validation loss = 7.06839306828334
# Finished sample 9
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 46.52988624364081
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 42.184881314277334
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 9.781707555874329
# enso_project.ESNHyperparams(120, 0.9, 0.1, 0.8, 0.0)
# Validation loss = 7.1404066105885775
# enso_project.ESNHyperparams(120, 0.9, 0.1, 0.8, 1.0e-6)
# Validation loss = 7.133841843897103
# enso_project.ESNHyperparams(120, 0.9, 0.1, 0.8, 1.0e-5)
# Validation loss = 7.0764402092616185
# Finished sample 10
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 47.01143024203676
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 43.14434533716143
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 9.788607258530215
# enso_project.ESNHyperparams(120, 0.9, 0.1, 0.8, 0.0)
# Validation loss = 8.347296338686848
# Finished sample 11
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 47.1426065823856
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 44.19501976123946
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 9.808301701725595
# Finished sample 12
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 47.17571011276202
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 44.931851828178836
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 9.817463866671693
# Finished sample 13
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 47.423592036798674
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 47.27481878294898
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 10.171275505931531
# Finished sample 14
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 48.191797561659065
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 10.92819320074003
# Finished sample 15
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 49.34887392877411
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 11.932834993841524
# Finished sample 16
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 50.439120269928004
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 12.466806276094164
# enso_project.ESNHyperparams(110, 1.0, 0.05, 1.0, 0.0)
# Validation loss = 12.304427288573203
# Finished sample 17
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 52.29448082305125
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 12.986709779061046
# enso_project.ESNHyperparams(110, 1.0, 0.05, 1.0, 0.0)
# Validation loss = 12.369864367107011
# Finished sample 18
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 54.12458197338099
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 13.110774108875171
# enso_project.ESNHyperparams(110, 1.0, 0.05, 1.0, 0.0)
# Validation loss = 12.745134877147276
# Finished sample 19
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 56.26118485636634
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 13.134995878222707
# Finished sample 20
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 58.30989511863344
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 13.135063187374126
# Finished sample 21
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 60.46900964235074
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 13.138804912136933
# Finished sample 22
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 61.82675918021522
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 13.215185140057097
# Finished sample 23
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 63.012726935754486
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 13.44301945021002
# Finished sample 24
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 64.37321391785885
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 13.83016369479568
# Finished sample 25
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 65.42595570227367
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 14.539023060122531
# Finished sample 26
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 65.7915360001361
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 15.756470180936788
# Finished sample 27
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 66.30912324343777
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 16.37680969799865
# enso_project.ESNHyperparams(110, 1.0, 0.05, 1.0, 0.0)
# Validation loss = 16.177294785810084
# Finished sample 28
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 67.99682165876074
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 16.41111271195491
# enso_project.ESNHyperparams(110, 1.0, 0.05, 1.0, 0.0)
# Validation loss = 16.403889759866512
# Finished sample 29
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 70.29117466075881
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 16.41273973664673
# Finished sample 30
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 72.50750040009348
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 16.414665269889767
# Finished sample 31
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 75.14221867439835
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 16.481923217531122
# Finished sample 32
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 76.53008819129207
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 16.48634492535696
# Finished sample 33
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 78.1907399247918
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 76.79648464529984
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 16.51358640673359
# Finished sample 34
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 79.83443793426746
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 76.91698077194816
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 16.62026687580694
# Finished sample 35
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 82.02605470356069
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 76.98457723381699
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 16.972446814281778
# Finished sample 36
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 84.89340391714795
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 77.2717427702719
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 17.78542411636979
# Finished sample 37
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 87.7261027011378
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 78.68437155275548
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 19.036668719708384
# Finished sample 38
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 89.15376749181668
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 79.85909387821857
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 19.818378256396038
# Finished sample 39
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 90.81510466301025
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 81.02873751886706
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 21.524111076376215
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 1.0e-6)
# Validation loss = 21.116511900778384
# Finished sample 40
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 91.6357382768102
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 81.42479453746999
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 23.005530695609362
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 1.0e-6)
# Validation loss = 21.860058384579474
# Finished sample 41
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 91.70464456403626
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 81.50092990224334
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 23.492756080733326
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 1.0e-6)
# Validation loss = 21.944198679743653
# Finished sample 42
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 91.70506788546328
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 81.59363835234188
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 23.913726563811743
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 1.0e-6)
# Validation loss = 21.984808647598463
# Finished sample 43
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 91.85820224036047
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 81.83187289287393
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 24.20493217796026
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 1.0e-6)
# Validation loss = 21.988384084175213
# Finished sample 44
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 92.35706095563805
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 82.02341212451913
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 24.48592527261079
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 1.0e-6)
# Validation loss = 21.989428381739252
# Finished sample 45
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 94.24755231578712
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 82.73722600437755
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 24.531229430661828
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 1.0e-6)
# Validation loss = 22.076340136304168
# Finished sample 46
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 96.92811997117033
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 85.07137349422482
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 24.53778819668458
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 1.0e-6)
# Validation loss = 22.262115919592247
# Finished sample 47
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 98.51873515489225
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 88.85981521303466
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 24.646125402516365
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 1.0e-6)
# Validation loss = 22.294762439613752
# Finished sample 48
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 100.11156915270483
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 93.77237279709145
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 24.77231891217173
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 1.0e-6)
# Validation loss = 22.314435523207116
# Finished sample 49
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 101.55245090145299
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 98.40861054175409
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 25.10378625138685
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 1.0e-6)
# Validation loss = 22.325423555601805
# Finished sample 50
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 102.16502904329259
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 99.9619365799714
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 26.359970800826968
# enso_project.ESNHyperparams(110, 0.8, 0.1, 0.1, 0.0)
# Validation loss = 26.201085146078228
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 1.0e-6)
# Validation loss = 22.785865009251282
# Finished sample 51
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 102.77398460729283
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 100.97972316599174
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 27.73170745135865
# enso_project.ESNHyperparams(110, 0.8, 0.1, 0.1, 0.0)
# Validation loss = 26.775219332002184
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 1.0e-6)
# Validation loss = 23.374572534489133
# Finished sample 52
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 103.4927498611907
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 101.66921695418452
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 28.80138936637222
# enso_project.ESNHyperparams(110, 0.8, 0.1, 0.1, 0.0)
# Validation loss = 27.375054202059584
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 1.0e-6)
# Validation loss = 23.831235460352566
# Finished sample 53
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 103.94462250847906
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 101.70114818875273
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 30.0454327311685
# enso_project.ESNHyperparams(110, 0.8, 0.1, 0.1, 0.0)
# Validation loss = 28.429952306611135
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 1.0e-6)
# Validation loss = 24.48761105841291
# Finished sample 54
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 105.17745156431731
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 102.17035268541359
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 30.562672899396865
# enso_project.ESNHyperparams(110, 0.8, 0.1, 0.1, 0.0)
# Validation loss = 29.057719020891096
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 1.0e-6)
# Validation loss = 24.70658017019475
# Finished sample 55
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 107.66242404502393
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 103.1402728715726
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 30.745251024210663
# enso_project.ESNHyperparams(110, 0.8, 0.1, 0.1, 0.0)
# Validation loss = 29.44070426635376
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 1.0e-6)
# Validation loss = 24.7647999066805
# Finished sample 56
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 111.3861846601816
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 103.1573804833314
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 30.792682002547092
# enso_project.ESNHyperparams(110, 0.8, 0.1, 0.1, 0.0)
# Validation loss = 29.656478147903442
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 1.0e-6)
# Validation loss = 24.77594925003823
# Finished sample 57
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 114.94876643237042
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 103.31878712021174
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 30.806786531771227
# enso_project.ESNHyperparams(110, 0.8, 0.1, 0.1, 0.0)
# Validation loss = 29.792509380302846
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 1.0e-6)
# Validation loss = 24.784183552223485
# Finished sample 58
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 117.96952485961793
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 103.52478950160486
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 30.808090111501222
# enso_project.ESNHyperparams(110, 0.8, 0.1, 0.1, 0.0)
# Validation loss = 29.842513543584335
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 1.0e-6)
# Validation loss = 24.784794896843366
# Finished sample 59
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 120.0924805399295
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 104.71555691440958
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 30.813605536509872
# enso_project.ESNHyperparams(110, 0.8, 0.1, 0.1, 0.0)
# Validation loss = 29.89669438106911
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 1.0e-6)
# Validation loss = 24.792598619714326
# Finished sample 60
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 122.19798939615346
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 110.4574450675145
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 30.919376648094357
# enso_project.ESNHyperparams(110, 0.8, 0.1, 0.1, 0.0)
# Validation loss = 29.897026034478706
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 1.0e-6)
# Validation loss = 24.795039356826443
# Finished sample 61
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 125.69224298109556
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 117.05372442737685
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 31.716817332659836
# enso_project.ESNHyperparams(110, 0.8, 0.1, 0.1, 0.0)
# Validation loss = 30.24078107885901
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 1.0e-6)
# Validation loss = 25.043470494831702
# Finished sample 62
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 129.46607347242653
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 117.05396928996328
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 33.17561002449491
# enso_project.ESNHyperparams(110, 0.8, 0.1, 0.1, 0.0)
# Validation loss = 31.15400699219817
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 1.0e-6)
# Validation loss = 25.525310990305098
# Finished sample 63
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 131.49719186737883
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 119.21654565443157
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 34.47893776027464
# enso_project.ESNHyperparams(110, 0.8, 0.1, 0.1, 0.0)
# Validation loss = 31.937210293025682
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 1.0e-6)
# Validation loss = 25.783793578615086
# Finished sample 64
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 132.0797039834758
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 119.29006438657404
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 35.286884563592686
# enso_project.ESNHyperparams(110, 0.8, 0.1, 0.1, 0.0)
# Validation loss = 32.279999390147026
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 1.0e-6)
# Validation loss = 25.80605884858317
# Finished sample 65
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 132.23265419709008
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 119.3354945193137
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 36.13699925053778
# enso_project.ESNHyperparams(110, 0.8, 0.1, 0.1, 0.0)
# Validation loss = 32.58699710822432
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 1.0e-6)
# Validation loss = 25.8107440804727
# Finished sample 66
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 132.33045385859674
# enso_project.ESNHyperparams(110, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 125.36211908459917
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 36.397942208994095
# enso_project.ESNHyperparams(110, 0.8, 0.1, 0.1, 0.0)
# Validation loss = 32.59567286374729
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 1.0e-6)
# Validation loss = 25.999188016617104
# Finished sample 67
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 133.23627877763653
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 36.403810971804894
# enso_project.ESNHyperparams(110, 0.8, 0.1, 0.1, 0.0)
# Validation loss = 32.89608462599653
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 1.0e-6)
# Validation loss = 27.182268781836047
# Finished sample 68
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 135.05166360951426
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 36.56225979309289
# enso_project.ESNHyperparams(110, 0.8, 0.1, 0.1, 0.0)
# Validation loss = 33.82717847879713
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 1.0e-6)
# Validation loss = 29.30617157928343
# Finished sample 69
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 138.73734478160446
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 36.987339254433785
# enso_project.ESNHyperparams(110, 0.8, 0.1, 0.1, 0.0)
# Validation loss = 35.60076359101684
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 1.0e-6)
# Validation loss = 32.31564503825505
# Finished sample 70
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 145.25901486472284
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 37.67222069729737
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 1.0e-6)
# Validation loss = 35.9751487868587
# Finished sample 71
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 154.10525383484693
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 38.34045155172988
# Finished sample 72
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 163.39390357013625
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 38.98353786140347
# Finished sample 73
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 170.82167470812473
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 39.50639967986573
# Finished sample 74
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 176.2706022204287
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 39.659132266294485
# Finished sample 75
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 183.67951506683013
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 39.98373943297065
# Finished sample 76
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 190.4800657464415
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 40.02333748132516
# Finished sample 77
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 195.54797257729348
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 40.072711185194535
# Finished sample 78
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 199.84601669359105
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 40.185291865012275
# Finished sample 79
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 202.56392916640888
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 40.71828933920888
# Finished sample 80
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 205.0134732155064
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 41.3845581436912
# Finished sample 81
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 207.4097504019685
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 42.225897211549565
# Finished sample 82
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 211.02300417581472
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 42.64171528479907
# Finished sample 83
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 215.02662936193803
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 42.752536842996946
# Finished sample 84
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 217.72704537176784
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 42.797088005109146
# Finished sample 85
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 219.95501357985532
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 42.82209455394625
# Finished sample 86
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 221.26132992574665
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 42.90359506054209
# Finished sample 87
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 221.73200133639824
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 42.90856986901563
# Finished sample 88
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 221.94074623723813
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 42.91919609883337
# Finished sample 89
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 221.94147296236403
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 42.93420871488996
# Finished sample 90
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 221.95613014988476
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 43.03169979959741
# Finished sample 91
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 222.43359312041756
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 43.03984731841718
# Finished sample 92
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 224.15392997462857
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 43.111857221273205
# Finished sample 93
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 225.57320693135065
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 43.18226555487511
# Finished sample 94
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 227.83055622232604
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 43.648599900004974
# Finished sample 95
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 229.8465720785508
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 43.88808819075028
# Finished sample 96
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 232.3127557027902
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 44.1094438147031
# Finished sample 97
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 236.1564957181502
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 44.536914393668056
# Finished sample 98
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 236.98002101506893
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 44.634263976406395
# Finished sample 99
# Algorithm stopped due to convergence of E₁-statistic. Valid embedding achieved ✓.
# enso_project.ESNHyperparams(100, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 237.30043771634388
# enso_project.ESNHyperparams(120, 0.8, 0.05, 0.1, 0.0)
# Validation loss = 44.75621041661778
# Finished sample 100

# %% [markdown]
# ### evaluate errors

# %%
pcc_vals = pcc(predictions, datasets_test);
rmse_vals = rmse(predictions, datasets_test);
hss_vals = hss(predictions, datasets_test);

# %%
plot(pcc_vals, label="CORR", xlabel="Lead Times (months)", ylabel="Error Index", title="ENSO Prediction, N=100")
plot!(rmse_vals, label="RMSE")
plot!(hss_vals, label="HSS")

# %%
plot(rmse_vals[1:10], label="RMSE", xlabel="Lead Times (months)", ylabel="Error Index", title="ENSO Prediction, N=100")

# %%
plot(pcc_vals[1:11], label="CORR", xlabel="Lead Times (months)", ylabel="Error Index", title="ENSO Prediction, N=100")
plot!(hss_vals[1:11], label="HSS")

# %% [markdown]
# ### store

# %%
CSV.write("C:/Users/lisah/Documents/Repos/enso_project.jl/temp_saves/redo_enso/errors/enso_L$(L)_N$(N)_predictions.csv", DataFrame(predictions, :auto))
CSV.write("C:/Users/lisah/Documents/Repos/enso_project.jl/temp_saves/redo_enso/errors/enso_L$(L)_N$(N)_testsets.csv", DataFrame(datasets_test, :auto))
# Out:
# "C:/Users/lisah/Documents/Repos/enso_project.jl/temp_saves/redo_enso/errors/enso_L30_N100_testsets.csv"

# %%
#predictions = Matrix(CSV.read("C:/Users/lisah/Documents/Repos/enso_project.jl/temp_saves/redo_enso/errors/enso_L$(L)_N$(N)_predictions.csv", DataFrame))
#datasets_test = Matrix(CSV.read("C:/Users/lisah/Documents/Repos/enso_project.jl/temp_saves/redo_enso/errors/enso_L$(L)_N$(N)_testsets.csv", DataFrame));
